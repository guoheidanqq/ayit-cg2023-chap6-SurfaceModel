# %%
uname -a

# %%
cat /etc/os-release

# %%
import torch

print("===== PyTorch Check =====")

# 版本
print("Torch version:", torch.__version__)

# 安装路径
print("Torch path:", torch.__file__)

# CUDA 是否可用
print("CUDA available:", torch.cuda.is_available())

# GPU 数量
print("GPU count:", torch.cuda.device_count())

# GPU 名称（如果有）
if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}:", torch.cuda.get_device_name(i))
else:
    print("No GPU detected")

# CUDA 版本（PyTorch编译时）
print("CUDA version (torch):", torch.version.cuda)

# cuDNN
print("cuDNN enabled:", torch.backends.cudnn.enabled)

# 实际计算测试
try:
    x = torch.rand(3, 3)
    print("CPU tensor OK")

    if torch.cuda.is_available():
        x = x.cuda()
        print("GPU tensor OK:", x)
    else:
        print("GPU test skipped")

except Exception as e:
    print("Error during tensor test:", e)

print("===== Done =====")
# Out:
# ===== PyTorch Check =====
# Torch version: 2.10.0+cu128
# Torch path: /home/aistudio/external-libraries/lib/python3.10/site-packages/torch/__init__.py
# CUDA available: True
# GPU count: 1
# GPU 0: Tesla V100-SXM2-32GB
# CUDA version (torch): 12.8
# cuDNN enabled: True
# CPU tensor OK
# Error during tensor test: CUDA error: uncorrectable ECC error encountered
# Search for `cudaErrorECCUncorrectable' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# ===== Done =====

# %%
conda create -n MyEnvForSD python==3.10.10

# %%
source activate MyEnvForSD

# %%
pip install trimesh

# %%
python --version

# %%
#use sh pytorch.sh
# give pytorch.sh   excute it in AI Studio


chmod +x pytorch.sh

# %%
# use vscode to change windows line end to lf
1. 在 VS Code 中转换换行符 (推荐)
VS Code 右下角的状态栏可以直接修改文件的换行格式：

在 VS Code 中打开 pytorch.sh。

观察右下角状态栏，你会看到 CRLF（这是 Windows 格式）。

点击 CRLF，在顶部弹出的菜单中选择 LF。

保存文件 (Ctrl + S)。

重新上传或同步到 AI Studio 即可。
